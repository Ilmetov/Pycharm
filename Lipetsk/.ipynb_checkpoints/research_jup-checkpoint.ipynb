# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/abon.csv')
df
# Out:
#          UID;REALIP;STTS;TARIF_INT;PRICE_INT;DATE_OFF
# 0                    10187356;;0;Снова вместе 50;300;
# 1                    10166903;;0;Снова вместе 70;350;
# 2                      10187434;;0;Интернет 2015;399;
# 3                    10187391;;0;Снова вместе 70;350;
# 4                    10187400;;0;Снова вместе 70;350;
# 5                      10007423;;0;Интернет 2015;399;
# 6                    10091407;;0;Снова вместе 50;300;
# 7                        10091136;;0;Интернет 99;399;
# 8                    10187425;;0;Снова вместе 50;300;
# 9                      10187317;;0;Интернет 2015;399;
# 10                   10187395;;0;Снова вместе 70;350;
# 11                   10081669;;0;Снова вместе 70;350;
# 12                   10017976;;0;Снова вместе 70;350;
# 13                       10187435;;0;Интернет 99;399;
# 14                       10187429;;0;Интернет 99;399;
# 15                     10187397;;0;Интернет 2015;399;
# ...
